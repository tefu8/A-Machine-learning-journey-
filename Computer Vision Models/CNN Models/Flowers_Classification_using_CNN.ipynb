# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.3.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
import os
import cv2
import random as rn

# %%
# %pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.12/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (1.7.4.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2025.10.5)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.5.1)

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/alxmamaev/flowers-recognition')
# Out:
# Skipping, found downloaded files in "./flowers-recognition" (use force=True to force download)

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='/content/flowers-recognition/flowers/daisy'
FLOWER_SUNFLOWER_DIR='/content/flowers-recognition/flowers/sunflower'
FLOWER_TULIP_DIR='/content/flowers-recognition/flowers/tulip'
FLOWER_DANDI_DIR='/content/flowers-recognition/flowers/dandelion' # Corrected directory name
FLOWER_ROSE_DIR='/content/flowers-recognition/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 764/764 [00:01<00:00, 496.07it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 733/733 [00:01<00:00, 399.87it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 984/984 [00:01<00:00, 522.53it/s]
# 2481

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 1052/1052 [00:01<00:00, 574.72it/s]
# 3533

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:01<00:00, 567.90it/s]
# 4317

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])

plt.tight_layout()

# %%
label_counts = pd.DataFrame(Z).value_counts()
display(label_counts)
# Out:
# 0
# Dandelion    1052
# Tulip         984
# Rose          784
# Daisy         764
# Sunflower     733
# Name: count, dtype: int64

# %%
plt.bar(label_counts.index, label_counts.values)

plt.xlabel('Flower Type')
plt.ylabel('Count')
plt.title('Frequency of Flower Types')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3425837387.py in <cell line: 0>()
# ----> 1 plt.bar(label_counts.index, label_counts.values)
#       2
#       3 plt.xlabel('Flower Type')
#       4 plt.ylabel('Count')
#       5 plt.title('Frequency of Flower Types')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2542             # However, it is also possible for y=0 for the default and height
#    2543             # to contain unit information.  This will prioritize the units of y.
# -> 2544             self._process_unit_info(
#    2545                 [("x", x), ("y", y), ("y", height)], kwargs, convert=False)
#    2546             if log:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2615             # Update from data if axis is already set but no unit is set yet.
#    2616             if axis is not None and data is not None and not axis.have_units():
# -> 2617                 axis.update_units(data)
#    2618         for axis_name, axis in axis_map.items():
#    2619             # Return if no axis is set.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1763         neednew = self._converter != converter
#    1764         self._set_converter(converter)
# -> 1765         default = self._converter.default_units(data, self)
#    1766         if default is not None and self.units is None:
#    1767             self.set_units(default)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in default_units(data, axis)
#     104         # the conversion call stack is default_units -> axis_info -> convert
#     105         if axis.units is None:
# --> 106             axis.set_units(UnitData(data))
#     107         else:
#     108             axis.units.update(data)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in __init__(self, data)
#     180         self._counter = itertools.count()
#     181         if data is not None:
# --> 182             self.update(data)
#     183
#     184     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in update(self, data)
#     215         for val in OrderedDict.fromkeys(data):
#     216             # OrderedDict just iterates over unique values in data.
# --> 217             _api.check_isinstance((str, bytes), value=val)
#     218             if convertible:
#     219                 # this will only be called so long as convertible is True.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in check_isinstance(types, **kwargs)
#      90                 names.remove("None")
#      91                 names.append("None")
# ---> 92             raise TypeError(
#      93                 "{!r} must be an instance of {}, not a {}".format(
#      94                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
import tensorflow as tf
np.random.seed(42)
rn.seed(42)
tf.set_random_seed(42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-580159811.py in <cell line: 0>()
#       2 np.random.seed(42)
#       3 rn.seed(42)
# ----> 4 tf.set_random_seed(42)
#
# AttributeError: module 'tensorflow' has no attribute 'set_random_seed'

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Flatten())
model.add(Dense(512, activation='relu')) # Corrected line
model.add(Dense(5, activation = "softmax"))

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 96)     │        83,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7776)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │    15,927,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,266,821 (65.87 MB)
#  Trainable params: 17,266,821 (65.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
History = model.fit(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.3113 - loss: 1.5127 - val_accuracy: 0.5127 - val_loss: 1.1844
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4688 - loss: 1.1237 - val_accuracy: 0.4826 - val_loss: 1.1828
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 673ms/step - accuracy: 0.5245 - loss: 1.1449 - val_accuracy: 0.5775 - val_loss: 1.0395
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5781 - loss: 1.0276 - val_accuracy: 0.5683 - val_loss: 1.1136
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 684ms/step - accuracy: 0.5880 - loss: 1.0560 - val_accuracy: 0.6273 - val_loss: 1.0066
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5391 - loss: 1.1420 - val_accuracy: 0.6574 - val_loss: 0.9373
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 670ms/step - accuracy: 0.6121 - loss: 0.9749 - val_accuracy: 0.6505 - val_loss: 0.9254
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6094 - loss: 0.9111 - val_accuracy: 0.6597 - val_loss: 0.9049
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 662ms/step - accuracy: 0.6230 - loss: 0.9337 - val_accuracy: 0.6771 - val_loss: 0.8330
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7266 - loss: 0.8663 - val_accuracy: 0.6933 - val_loss: 0.8174
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 687ms/step - accuracy: 0.6735 - loss: 0.8332 - val_accuracy: 0.6887 - val_loss: 0.8136
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7188 - loss: 0.8166 - val_accuracy: 0.6875 - val_loss: 0.8821
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 664ms/step - accuracy: 0.6762 - loss: 0.8387 - val_accuracy: 0.7141 - val_loss: 0.7934
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7188 - loss: 0.7787 - val_accuracy: 0.6991 - val_loss: 0.8352
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 680ms/step - accuracy: 0.6773 - loss: 0.8077 - val_accuracy: 0.6921 - val_loss: 0.7768
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6406 - loss: 0.8856 - val_accuracy: 0.7025 - val_loss: 0.7709
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 673ms/step - accuracy: 0.7131 - loss: 0.7441 - val_accuracy: 0.6979 - val_loss: 0.7503
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6484 - loss: 0.8470 - val_accuracy: 0.7095 - val_loss: 0.7450
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 700ms/step - accuracy: 0.7029 - loss: 0.7754 - val_accuracy: 0.7002 - val_loss: 0.8112
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6875 - loss: 0.7028 - val_accuracy: 0.7049 - val_loss: 0.7715
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 679ms/step - accuracy: 0.7111 - loss: 0.7404 - val_accuracy: 0.7419 - val_loss: 0.7025
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7656 - loss: 0.7386 - val_accuracy: 0.7488 - val_loss: 0.6962
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 694ms/step - accuracy: 0.7224 - loss: 0.7014 - val_accuracy: 0.7118 - val_loss: 0.7332
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7344 - loss: 0.6943 - val_accuracy: 0.7338 - val_loss: 0.7200
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 701ms/step - accuracy: 0.7427 - loss: 0.6746 - val_accuracy: 0.7303 - val_loss: 0.7116
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7578 - loss: 0.6737 - val_accuracy: 0.7049 - val_loss: 0.7792
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 696ms/step - accuracy: 0.7473 - loss: 0.6610 - val_accuracy: 0.7245 - val_loss: 0.7523
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7656 - loss: 0.6671 - val_accuracy: 0.7083 - val_loss: 0.7837
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 665ms/step - accuracy: 0.7662 - loss: 0.6258 - val_accuracy: 0.7303 - val_loss: 0.7076
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7188 - loss: 0.7388 - val_accuracy: 0.7338 - val_loss: 0.7371
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 669ms/step - accuracy: 0.7615 - loss: 0.6277 - val_accuracy: 0.7280 - val_loss: 0.6986
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7656 - loss: 0.6497 - val_accuracy: 0.7477 - val_loss: 0.6363
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 676ms/step - accuracy: 0.7438 - loss: 0.6695 - val_accuracy: 0.7512 - val_loss: 0.6937
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7109 - loss: 0.7098 - val_accuracy: 0.7650 - val_loss: 0.6543
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 670ms/step - accuracy: 0.7673 - loss: 0.6223 - val_accuracy: 0.7847 - val_loss: 0.6164
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8359 - loss: 0.4524 - val_accuracy: 0.7882 - val_loss: 0.6199
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 696ms/step - accuracy: 0.7904 - loss: 0.5520 - val_accuracy: 0.7384 - val_loss: 0.7306
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7891 - loss: 0.5100 - val_accuracy: 0.7454 - val_loss: 0.6869
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 659ms/step - accuracy: 0.7949 - loss: 0.5489 - val_accuracy: 0.7616 - val_loss: 0.6317
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8203 - loss: 0.5137 - val_accuracy: 0.7454 - val_loss: 0.6651
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 694ms/step - accuracy: 0.7926 - loss: 0.5569 - val_accuracy: 0.7766 - val_loss: 0.5900
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7500 - loss: 0.6619 - val_accuracy: 0.7801 - val_loss: 0.6023
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 664ms/step - accuracy: 0.7980 - loss: 0.5105 - val_accuracy: 0.7095 - val_loss: 0.7452
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7734 - loss: 0.5885 - val_accuracy: 0.7188 - val_loss: 0.7192
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 663ms/step - accuracy: 0.7883 - loss: 0.5527 - val_accuracy: 0.7836 - val_loss: 0.6464
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8047 - loss: 0.5483 - val_accuracy: 0.7905 - val_loss: 0.6328
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 696ms/step - accuracy: 0.8103 - loss: 0.5076 - val_accuracy: 0.7743 - val_loss: 0.6297
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8047 - loss: 0.4792 - val_accuracy: 0.7789 - val_loss: 0.6267
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 664ms/step - accuracy: 0.8301 - loss: 0.4631 - val_accuracy: 0.7350 - val_loss: 0.6965
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7734 - loss: 0.6162 - val_accuracy: 0.7500 - val_loss: 0.6726
